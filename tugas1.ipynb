# %% [markdown]
# <a href="https://colab.research.google.com/github/rifaiahsani/rifaiahsani/blob/main/tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nama : Rifa'i Nur Ahsani
# Kelas: M2025E
# NIM  : 25030214134

z = int(input("Masukkan angka : "))
if (z % 2) == 0:
    print(f"{z} Bilangan Genap")
else:
    print(f"{z} Bilangan Ganjil")
# Out:
# Masukkan angka : 14
# 14 Bilangan Genap
